# %% [markdown]
# <a href="https://colab.research.google.com/github/akash1331/inae-serb/blob/new/text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from attention import AttentionLayer

# %%
import numpy as np
import pandas as pd
import re           
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras_preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("train.csv")
data.head()
# Out:
#             FileName  \
# 0  S0262885614000857
# 1  S0169260715300419
# 2  S0169260715003260
# 3  S0262885613001443
# 4  S0262885614000511
#
#                                                                                                                                                                                                   Abstract  \
# 0   This paper introduces four classes of rotation invariant orthogonal moments by generalizing four existing moments that use harmonic functions in their radial kernels . Members of these classes sh...
# 1   In this paper a MATLAB based graphical user interface software tool for general biomedical signal processing and analysis of functional neuroimaging data is introduced . Specifically electroencep...
# 2   Background and objective A markerless low cost prototype has been developed for the determination of some spatio temporal parameters of human gait step length step width and cadence have been con...
# 3   This paper presents an improved multiple instance learning tracker representing target with Distribution Fields and building a weighted geometric mean MIL classifier . Firstly we adopt DF layer a...
# 4   Text based image retrieval may perform poorly due to the irrelevant and or incomplete text surrounding the images in the web pages . In such situations visual content of the images can be leverag...
#
#                                                                                                                                                                                                        RHS
# 0  We generalize polar harmonic transforms for pattern description recognition. The generalization maintains beneficial properties of existing transforms. The completeness of the corresponding basis ...
# 1  Design of a MATLAB based GUI tool for general biomedical signal processing and analysis. EEG and ECG signals can be processed and analyzed by the designed tool. The easy to use and easy to learn i...
# 2  A markerless low cost system for the estimation of some spatial temporal parameters of human gait. A system usable on not instrumented treadmill. A system characterized by a very high level of aut...
# 3  We adopt Distribution Field DF layer as feature instead of traditional Haar like one to robustly model the target. We derive an online weighted geometric mean MIL classifier to select the most dis...
# 4  A system that constructs multi instance bags from text based retrieval order. Ensemble of MI classifiers is learned using these multi instance bags. We report image re ranking performance on multi...

# %%
data1 = pd.read_csv('val.csv')
data1.head(1)
data1 = data1[['Abstract','RHS']]
data1.head(1)
# Out:
#                                                                                                                                                                                                   Abstract  \
# 0   Human face can be seen as a soft tissue organ complex with a large investing network of musculature . Due to its complexity most existing computational models approximate these muscular structure...
#
#                                                                                                                                                                                                        RHS
# 0  We model the deformation of the human face due to muscle contraction. 3 D muscles with anatomical geometry and fibre orientation is used. Muscle forces are represented as discrete point load at th...

# %%
data1.isnull().sum()
# Out:
# Abstract    0
# RHS         0
# dtype: int64

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data = data[['Abstract','RHS']]
data.head()
# Out:
#                                                                                                                                                                                                   Abstract  \
# 0   This paper introduces four classes of rotation invariant orthogonal moments by generalizing four existing moments that use harmonic functions in their radial kernels . Members of these classes sh...
# 1   In this paper a MATLAB based graphical user interface software tool for general biomedical signal processing and analysis of functional neuroimaging data is introduced . Specifically electroencep...
# 2   Background and objective A markerless low cost prototype has been developed for the determination of some spatio temporal parameters of human gait step length step width and cadence have been con...
# 3   This paper presents an improved multiple instance learning tracker representing target with Distribution Fields and building a weighted geometric mean MIL classifier . Firstly we adopt DF layer a...
# 4   Text based image retrieval may perform poorly due to the irrelevant and or incomplete text surrounding the images in the web pages . In such situations visual content of the images can be leverag...
#
#                                                                                                                                                                                                        RHS
# 0  We generalize polar harmonic transforms for pattern description recognition. The generalization maintains beneficial properties of existing transforms. The completeness of the corresponding basis ...
# 1  Design of a MATLAB based GUI tool for general biomedical signal processing and analysis. EEG and ECG signals can be processed and analyzed by the designed tool. The easy to use and easy to learn i...
# 2  A markerless low cost system for the estimation of some spatial temporal parameters of human gait. A system usable on not instrumented treadmill. A system characterized by a very high level of aut...
# 3  We adopt Distribution Field DF layer as feature instead of traditional Haar like one to robustly model the target. We derive an online weighted geometric mean MIL classifier to select the most dis...
# 4  A system that constructs multi instance bags from text based retrieval order. Ensemble of MI classifiers is learned using these multi instance bags. We report image re ranking performance on multi...

# %%
data[['Abstract']].isnull().sum()
# Out:
# Abstract    0
# dtype: int64

# %%
data[['RHS']].isnull().sum()
# Out:
# RHS    0
# dtype: int64

# %%
data[['Abstract']].isna().sum()
# Out:
# Abstract    0
# dtype: int64

# %%
data[['RHS']].isna().sum()
# Out:
# RHS    0
# dtype: int64

# %%
data[['Abstract']].duplicated().sum()
# Out:
# 2

# %%
data[['RHS']].duplicated().sum()
# Out:
# 1

# %%
# data[['Abstract']].drop_duplicates(inplace = True)

# %%
data.drop_duplicates(inplace = True)

# %%
data[['RHS']].duplicated().sum()
# Out:
# 0

# %%
data[['Abstract']].duplicated().sum()
# Out:
# 1

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english')) 
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# cleaned_text = []
# for t in data['Abstract']:
#     cleaned_text.append(text_cleaner(t))

# %%
data['Abstract_cleaned'] = data['Abstract'].apply(text_cleaner)

# %%
data1['Abstract_cleaned'] = data1['Abstract'].apply(text_cleaner)

# %%
# data.drop([['cleantext']],inplace = True)
# data.head()
data = data[['Abstract','RHS','Abstract_cleaned']]
data.head()
# Out:
#                                                                                                                                                                                                   Abstract  \
# 0   This paper introduces four classes of rotation invariant orthogonal moments by generalizing four existing moments that use harmonic functions in their radial kernels . Members of these classes sh...
# 1   In this paper a MATLAB based graphical user interface software tool for general biomedical signal processing and analysis of functional neuroimaging data is introduced . Specifically electroencep...
# 2   Background and objective A markerless low cost prototype has been developed for the determination of some spatio temporal parameters of human gait step length step width and cadence have been con...
# 3   This paper presents an improved multiple instance learning tracker representing target with Distribution Fields and building a weighted geometric mean MIL classifier . Firstly we adopt DF layer a...
# 4   Text based image retrieval may perform poorly due to the irrelevant and or incomplete text surrounding the images in the web pages . In such situations visual content of the images can be leverag...
#
#                                                                                                                                                                                                        RHS  \
# 0  We generalize polar harmonic transforms for pattern description recognition. The generalization maintains beneficial properties of existing transforms. The completeness of the corresponding basis ...
# 1  Design of a MATLAB based GUI tool for general biomedical signal processing and analysis. EEG and ECG signals can be processed and analyzed by the designed tool. The easy to use and easy to learn i...
# 2  A markerless low cost system for the estimation of some spatial temporal parameters of human gait. A system usable on not instrumented treadmill. A system characterized by a very high level of aut...
# 3  We adopt Distribution Field DF layer as feature instead of traditional Haar like one to robustly model the target. We derive an online weighted geometric mean MIL classifier to select the most dis...
# 4  A system that constructs multi instance bags from text based retrieval order. Ensemble of MI classifiers is learned using these multi instance bags. We report image re ranking performance on multi...
#
#                                                                                                                                                                                           Abstract_cleaned
# 0  paper introduces four classes rotation invariant orthogonal moments generalizing four existing moments use harmonic functions radial kernels members classes share beneficial properties image repre...
# 1  paper matlab based graphical user interface software tool general biomedical signal processing analysis functional neuroimaging data introduced specifically electroencephalography electrocardiogra...
# 2  background objective markerless low cost prototype developed determination spatio temporal parameters human gait step length step width cadence considered smartphone high definition webcam used me...
# 3  paper presents improved multiple instance learning tracker representing target distribution fields building weighted geometric mean mil classifier firstly adopt layer feature instead traditional h...
# 4  text based image retrieval may perform poorly due irrelevant incomplete text surrounding images web pages situations visual content images leveraged improve image ranking performance paper look pr...

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

# %%
data['RHS_cleaned'] = data['RHS'].apply(summary_cleaner)
data1['RHS_cleaned'] = data1['RHS'].apply(text_cleaner)
data1['RHS_cleaned'] = data1['RHS_cleaned'].apply(lambda x:'_START_' +x+ '_END_')

# %%
data.head(1) #trianing data
# Out:
#                                                                                                                                                                                                   Abstract  \
# 0   This paper introduces four classes of rotation invariant orthogonal moments by generalizing four existing moments that use harmonic functions in their radial kernels . Members of these classes sh...
#
#                                                                                                                                                                                                        RHS  \
# 0  We generalize polar harmonic transforms for pattern description recognition. The generalization maintains beneficial properties of existing transforms. The completeness of the corresponding basis ...
#
#                                                                                                                                                                                           Abstract_cleaned  \
# 0  paper introduces four classes rotation invariant orthogonal moments generalizing four existing moments use harmonic functions radial kernels members classes share beneficial properties image repre...
#
#                                                                                                                                                                                                RHS_cleaned
# 0  we generalize polar harmonic transforms for pattern description recognition the generalization maintains beneficial properties of existing transforms the completeness of the corresponding basis se...

# %%
data1.head(1) #testing data
# Out:
#                                                                                                                                                                                                   Abstract  \
# 0   Human face can be seen as a soft tissue organ complex with a large investing network of musculature . Due to its complexity most existing computational models approximate these muscular structure...
#
#                                                                                                                                                                                                        RHS  \
# 0  We model the deformation of the human face due to muscle contraction. 3 D muscles with anatomical geometry and fibre orientation is used. Muscle forces are represented as discrete point load at th...
#
#                                                                                                                                                                                           Abstract_cleaned  \
# 0  human face seen soft tissue organ complex large investing network musculature due complexity existing computational models approximate muscular structures using simple geometries curves primitive ...
#
#                                                                                                                                                                                                RHS_cleaned
# 0  _START_model deformation human face due muscle contraction muscles anatomical geometry fibre orientation used muscle forces represented discrete point load integration points increasing number emb...

# %%
x_tr = data['Abstract_cleaned']
y_tr = data['RHS_cleaned']
x_val = data1['Abstract_cleaned']
y_val = data1['RHS_cleaned']

# %%
max_len_text = 30
max_len_summary = 8

# %%
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
# Attentionlayer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  embedding (Embedding)          (None, 30, 500)      7714000     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 30, 500),    2002000     ['embedding[0][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 30, 500),    2002000     ['lstm[0][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  embedding_1 (Embedding)        (None, None, 500)    5025000     ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 30, 500),    2002000     ['lstm_1[1][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  lstm_3 (LSTM)                  [(None, None, 500),  2002000     ['embedding_1[0][0]',
#                                  (None, 500),                     'lstm_2[0][1]',
#                                  (None, 500)]                     'lstm_2[0][2]']
#
#  attention_layer (AttentionLaye  ((None, None, 500),  500500     ['lstm_2[0][0]',
#  r)                              (None, None, 30))                'lstm_3[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 1000)   0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  time_distributed (TimeDistribu  (None, None, 10050)  10060050   ['concat_layer[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 31,307,550
# Trainable params: 31,307,550
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=50)
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=15,callbacks=[es],batch_size=200, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/15
# 10/10 [==============================] - 20s 357ms/step - loss: 8.0219 - accuracy: 0.0375 - val_loss: 8.3210 - val_accuracy: 0.0000e+00
# Epoch 2/15
# 10/10 [==============================] - 2s 176ms/step - loss: 6.9986 - accuracy: 0.0497 - val_loss: 8.3176 - val_accuracy: 0.0000e+00
# Epoch 3/15
# 10/10 [==============================] - 2s 178ms/step - loss: 6.8521 - accuracy: 0.0562 - val_loss: 8.3590 - val_accuracy: 0.0000e+00
# Epoch 4/15
# 10/10 [==============================] - 2s 177ms/step - loss: 6.7247 - accuracy: 0.0698 - val_loss: 8.6501 - val_accuracy: 0.0000e+00
# Epoch 5/15
# 10/10 [==============================] - 2s 183ms/step - loss: 6.5514 - accuracy: 0.0813 - val_loss: 8.9130 - val_accuracy: 0.0000e+00
# Epoch 6/15
# 10/10 [==============================] - 2s 180ms/step - loss: 6.4099 - accuracy: 0.0892 - val_loss: 9.0773 - val_accuracy: 0.0000e+00
# Epoch 7/15
# 10/10 [==============================] - 2s 182ms/step - loss: 6.2343 - accuracy: 0.0965 - val_loss: 9.2296 - val_accuracy: 0.0000e+00
# Epoch 8/15
# 10/10 [==============================] - 2s 183ms/step - loss: 6.0992 - accuracy: 0.1016 - val_loss: 9.4214 - val_accuracy: 0.0000e+00
# Epoch 9/15
# 10/10 [==============================] - 2s 183ms/step - loss: 5.8865 - accuracy: 0.1123 - val_loss: 9.6571 - val_accuracy: 0.0000e+00
# Epoch 10/15
# 10/10 [==============================] - 2s 183ms/step - loss: 5.7198 - accuracy: 0.1189 - val_loss: 9.7125 - val_accuracy: 0.0000e+00
# Epoch 11/15
# 10/10 [==============================] - 2s 185ms/step - loss: 5.5449 - accuracy: 0.1216 - val_loss: 9.9746 - val_accuracy: 0.0000e+00
# Epoch 12/15
# 10/10 [==============================] - 2s 184ms/step - loss: 5.3767 - accuracy: 0.1263 - val_loss: 9.8890 - val_accuracy: 0.0029
# Epoch 13/15
# 10/10 [==============================] - 2s 182ms/step - loss: 5.2072 - accuracy: 0.1345 - val_loss: 10.2019 - val_accuracy: 0.0057
# Epoch 14/15
# 10/10 [==============================] - 2s 180ms/step - loss: 5.0464 - accuracy: 0.1371 - val_loss: 10.3135 - val_accuracy: 0.0043
# Epoch 15/15
# 10/10 [==============================] - 2s 180ms/step - loss: 4.8893 - accuracy: 0.1456 - val_loss: 10.2680 - val_accuracy: 0.0029

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

            # Exit condition: either hit max length or find stop word.
            if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(1,len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: involving specific material models loads applied well usually perfect geometry provide unified approach prediction bifurcation propagation applied general conditions furthermore show instability conditions hand propagates agreement propagation arterial wall tissue
# Original summary: formation shown propagate propagate arterial wall tissue
# Predicted summary:  the proposed method is robust to the
#
#
# Review: description approach modular product family development compared earlier publication considering research method current situation analysed first original method description consider relevant aspects though considered industrial case discussed paper conclusion supported
# Original summary: helps defining design information related key concepts
# Predicted summary:  that the performance of the art system
#
#
# Review: evolution inertia friction process distributions dynamic fraction average grain size inertia friction process obtained analyzed inertia friction experiments ring parts carried comparison results show simulated results agree well measured ones
# Original summary: fraction average grain size process predicted accurately
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: approximation defined sufficiently fine mesh extended finite element method used order alleviate meshing issues mesh level set function built cad input means automated approach strategy verified analytical solutions real aerospace
# Original summary: order treat massive parts encouraging results shown
# Predicted summary:  that the effectiveness of the art method
#
#
# Review: analysis original cad drawings bridge combination vibration waveforms generated vehicles spectrum demonstrated realistic consistency findings showing correlations physical damage areas bridge excited mode shapes operational loading tend cause types damage
# Original summary: bridge bridge deterioration associated traffic first mode
# Predicted summary:  the proposed method is robust to the
#
#
# Review: method performed composite stiffened panel effect noise performance identification also discussed results study show developed approach capable identifying impact location reconstructing force history accurately reducing material uncertainty modal updating procedure
# Original summary: validated composite panel effect noise finally discussed
# Predicted summary:  the proposed method is robust to the
#
#
# Review: indicates use original method leads presence phase error long term dynamic simulation models improve accuracy dynamic response modification original based minimization residual linearization point proposed parameters affecting accuracy modified studied
# Original summary: point factors affecting accuracy modified studied detail
# Predicted summary:  the proposed method is robust to the
#
#
# Review: shape functions shown fea successfully carried meshes cell shape functions constructed oriented linear combination classic element shape functions numerical examples illustrate correctness proposed framework potential applications proposed framework also illustrated
# Original summary: mesh numerical results provided validate proposed theory
# Predicted summary:  results for the use of the art
#
#
# Review: four benchmark problems known analytical solutions illustrate effect meshes accuracy computed solution illustrations intended raise awareness subtle important relationship mesh stress field orientation presented benefit finite element analysts structural engineering
# Original summary: highly relevant shell modelling structures global shear
# Predicted summary:  the proposed method is robust to the
#
#
# Review: professional lives associated fixation different ways experience prior design failures thought encourage fixation whilst experience varied solutions thought fixation fixation episodes reflecting described means designers could episodes future thus creative
# Original summary: wide range contextual factors fixation helps designers
# Predicted summary:  results for the precise of the internet
#
#
# Review: contribution total stress concrete external contribution traction vector components contact contribution traction vector components ambient temperature conditions conditions elevated temperature horizontal direction vertical direction gaussian integration node beam side plates
# Original summary: side plates impact ultimate fire resistance beam
# Predicted summary:  the proposed method is robust to the
#
#
# Review: results obtained two operating conditions given technique applied crack propagation residual stress field presented cracking path obtained plate compared obtained using fem coupled technique shown computed crack path experimental observations
# Original summary: cracking problems residual stress fields computed fem
# Predicted summary:  the proposed method is robust to the
#
#
# Review: boundary conditions frequencies plate dramatic dependence residual surface stress surface elasticity plates present model efficient tool analysis static dynamic mechanical behaviors nanoscale plates complex geometry boundary loading conditions material properties
# Original summary: efficient tool analysis design nanoscale plate devices
# Predicted summary:  the proposed method is robust to the
#
#
# Review: theory current formulation effects load position also easily captured virtue freedom provided beam axis selection comparisons solutions literature based shell element models presented example designated illustrate significance shear deformation effect
# Original summary: easily captured freedom provided beam axis selection
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: sparse communication extension mapreduce based map side join usually characterized better efficiency compared origin although much nevertheless mapreduce still remains good alternative enormous networks whose data structures fit local memories
# Original summary: design pattern may improve original mapreduce performance
# Predicted summary:  the proposed of the art of the
#
#
# Review: common variability language using genetic algorithm finds nearly optimal configurations run time using information provided variability model also specify case study use evaluate approach showing efficient suitable devices scarce resources
# Original summary: user applying dynamic reconfiguration battery life utility
# Predicted summary:  that the minimum drive of the internet
#
#
# Review: provides valuable insight graphic design practice regard visual accessibility hoped work subsequent research help develop new procedures processes tools improve client designer communication assist graphic designers creating visually accessible designs
# Original summary: accessibility need investigate development ethical design codes
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: matrix material elastic compliance coefficients element boundary element traction natural boundary applied boundary traction transformation matrix equivalent stress modes constants displacement field displacement terms first order basic deformation mode element
# Original summary: modes optimal assumed stress modes hybrid element
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: aims make comprehensive review classification wavelet based numerical analysis note merits drawbacks future directions thus present review helps readers identify research starting points wavelet based numerical analysis guides researchers practitioners
# Original summary: based numerical analysis methods categorized five types
# Predicted summary:  results for the proposed of the proposed
#
#
# Review: experimental results literature finite element simulation using results first mode frequency partially beam validated results key point proposed model partial delamination beams analyzed using beam model rather using plate models
# Original summary: models proposed validated dimensional finite element simulation
# Predicted summary:  the proposed method is robust to the
#
#
# Review: distinction models ramp using solve topology optimization problems body forces investigated indicates although two interpolation models able yield similar optimal results suitable parameters chosen superiority ramp model get clearer topologies
# Original summary: problems suggestions choose appropriate parameters ramp given
# Predicted summary:  that the performance of the art system
#
#
# Review: relocation well cell key model bifurcation parameter identified formed association motor proteins robustness generality applicability numerical methodology allows tackle similar problems developmental biology biomedicine plant biology similar mechanisms routinely used
# Original summary: allows solve similar complex problems multi dimensions
# Predicted summary:  results for the proposed of the proposed
#
#
# Review: close shear plane stress distributions different layers depended angles specified layer effectiveness global local model procedure reducing computation effort obvious methodology applicable detailed stress strain analysis problems large scale structures
# Original summary: local procedure reducing computation effort quite obvious
# Predicted summary:  the proposed method is robust to the
#
#
# Review: values continuous tension compression tension compression tension compression tests conducted newly developed testing system calibration model accurately predict yielding asymmetry behavior stress strain curve unusual shape result activation deformation mechanisms
# Original summary: curves plane cyclic loadings sheets could exactly
# Predicted summary:  the proposed method is robust to the
#
#
# Review: guarantees convergence furthermore number iterations nonlinear numerical solution decreased solution speed significantly increased three different problems analyzed developed method results show good agreement commercially available finite element software experimental results
# Original summary: holder zone method capable applied complicated geometries
# Predicted summary:  results for the precise of the structures
#
#
# Review: energy modes moreover refined assumed stress element method developed improve element accuracy numerical examples presented show proposed model indeed possesses higher accuracy pass enhanced patch test capture scale effects microstructure
# Original summary: stresses smooth technique improve accuracy stress accuracy
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: order elements linear analysis new interpolation coincides higher order linked interpolation known produce exact results polynomial loading numerical analysis performed representative examples illustrates performance configuration dependent interpolation compared lagrangian interpolation
# Original summary: obtained show good performance regardless integration order
# Predicted summary:  that the performance of the art system
#
#
# Review: called event sets highly customizable used analyse performance scalability user defined queries evaluate effects various query processing strategies experimental results show simulate existing systems large big data scenarios accuracy precision
# Original summary: experimental results showed effective big data simulations
# Predicted summary:  that the effectiveness of the art method
#
#
# Review: expressions stiffness matrix force vector developed based connection coefficients inner products basis functions derivatives order validate formulation several examples increasing level complexity tested results compared analytical standard beam element solutions
# Original summary: results compared analytical standard beam element solutions
# Predicted summary:  that the minimum drive of the internet
#
#
# Review: integration method numerical examples thin plate six bar structure mindlin plate shell structure verify effectiveness accuracy proposed method hence proposed method considered alternative engineering method static response analysis stochastic structures
# Original summary: distribution function static response calculated effectiveness investigated
# Predicted summary:  the proposed method is robust to the
#
#
# Review: design process however whilst studies follow similar approach compared show great variety methods used results obtained discuss diversity offering methodological inspiration fixation research providing recommendations future studies might conducted reported
# Original summary: effects suggest inclusion methods propose research questions
# Predicted summary:  results for the precise of mobile structures
#
#
# Review: stable easy implemented finally three numerical examples demonstrated validity proposed method capacity predicting changes respect changes design parameters terms first second order studied application analysis two stage floating isolation system
# Original summary: eigenvalues proposed space algorithm computing eigenvalues proposed
# Predicted summary:  that the effectiveness of the art method
#
#
# Review: position pre determined considered plates series continuum governing differential equations include surface energy neutral plane position effects derived comparison continuum analysis ultra thin plates without incorporating surface energy effects presented
# Original summary: analysis ultra thin films based surface conditions
# Predicted summary:  that the state of the art method
#
#
# Review: load displacement responses ultimate load results compare well previous studies concluded using one element per member monitoring end sections accurately likely predict nonlinear responses three dimensional semi rigid steel frames
# Original summary: elements proposed program developed daily engineering design
# Predicted summary:  the proposed method is robust to the
#
#
# Review: subjected plane loads investigated variety examples effects boundary conditions applied loads critical buckling loads buckling mode shapes also assessed class order show efficacy present mathematical technique predict buckling mode shapes
# Original summary: results validated existing results new results presented
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: based cell scheme present method calculation cell carried meshfree method galerkin weak form local search implemented interpolation numerical examples show present method high computational efficiency convergence good accuracy also obtained
# Original summary: also shows present method good accuracy convergence
# Predicted summary:  the proposed method is robust to the
#
#
# Review: correction parameter approximated stress measure addressed furthermore present new regional constraint method based sorting algorithm applicability limitations newly developed framework discussed context application several stress based topology optimizations multiple materials
# Original summary: new regional constraint method based algorithm developed
# Predicted summary:  the proposed method is robust to the
#
#
# Review: models efficiently achieve optimum design features differentiate directional discrete methods making method suitable design multi material compliant mechanisms numerous examples presented show validity multi procedure design multi material compliant mechanisms
# Original summary: validity proposed formation design complex compliant mechanisms
# Predicted summary:  the proposed method is robust to the
#
#
# Review: method tested model model analysis variance approach employed evaluate parameter variability significance select updating variable results study show developed hierarchical method capable identifying input parameters temperature field structure good accuracy
# Original summary: variance method used dynamic structure model updating
# Predicted summary:  the proposed method is robust to the
#
#
# Review: function stress tensor physical component stress tensor strain tensor derivative respect physical component thermal strain tensor initial strain tensor arbitrary curve surrounding angle material density symbols listed defined appear text
# Original summary: integral may easily correlated establish failure criteria
# Predicted summary:  the proposed method is robust to the
#
#
# Review: convergence predicted crack front geometry guarantee convergence distribution stress intensity factors along crack front also determined models considered using smaller overall mesh size effective way decreasing discretization error increasing level
# Original summary: mesh energy norm used indicator solution convergence
# Predicted summary:  way for the decision of mobile structures
#
#
# Review: time scheduled algorithm hidden terminal problem avoidance appropriately exploits available bandwidth accomplishes straightforward coordination sender receiver pair finally analysis simulation experiments presented results carefully discussed demonstrating effectiveness proposals wmsn arena
# Original summary: intensive performance evaluation study discussed validate proposals
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: zones cooling rate locally controlled hot forming process part hardness distribution evolution predicted compared experimental results proving validation numerical model taking account influence transformation plasticity deformation history phase transformation kinetics
# Original summary: influence transformation deformation history phase transformation kinetics
# Predicted summary:  that the performance of the art algorithms
#
#
# Review: fashion greatly accelerates evaluation hessian matrices numerical example strain gradient damage mechanics problem given end results show proposed technique capable evaluating laplacian equivalent strains potential even higher order derivative recovery
# Original summary: verified recovery equivalent strains damage mechanics model
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: individuals perform protect implicit approach belief scholarly information automatically leads awareness converts actions however people actions face risk determined objective scientific information also information perceived light people expectations previous experiences
# Original summary: responsibility challenges resulted human cultural resource factors
# Predicted summary:  that the effectiveness of the art method
#
#
# Review: numerically simulated convergence analysis carried results force versus displacement distributions plastic parameters provided numerical results show expected analysis error controlled mesh refinement presented formulation model finite elastic finite plastic strains
# Original summary: free behavior reliable stress fields mechanical problems
# Predicted summary:  that the performance of the art system
#
#
# Review: period analysis acceleration increasing mass density model careful convergence study carried gain understanding choice proper values parameters artificial acceleration techniques efficient accurate simulation predictions provide practical experience simulations explicit analysis
# Original summary: valuable practical experience simulations explicit analysis provided
# Predicted summary:  the proposed method is robust to the
#
#
# Review: adapted strain based formulation generalized method used enforce numerical dissipation higher modes update procedure needed iteration process discussed detail exact linearization governing equations also presented performance formulation demonstrated numerical examples
# Original summary: linearization update procedure novel presented first time
# Predicted summary:  results for the proposed of the proposed
#
#
# Review: strength enhancement restricted corner regions roll forming may also moderate gain flat regions given longitudinal forces occurring forming process may relatively high thus lead plastic straining finite element method regarded
# Original summary: reported simulation numerical predictions compared theoretical models
# Predicted summary:  results for the use of the art
#
#
# Review: order assess performances previous eas formulations analyzed alternative formulation eas parameters proposed applied set benchmark linear nonlinear problems solid solid shell elements order evaluate occurrence locking phenomena infer potential applications
# Original summary: locking formulation plane reduced integration stabilization presented
# Predicted summary:  the proposed of the art of the
#
#
# Review: simulation developed scheduled multi pass rough rolling process shape steel carried accuracy equations validated comparisons calculated mill load measured ones numerical orthogonal experiment designed investigate effects rolling parameters microstructure evolution
# Original summary: orthogonal experiment designed investigate effects parameters evolution
# Predicted summary:  the proposed of the art of the
#
#
# Review: verified comparing effective obtained fixed grid finite element method obtained finite element method anisotropy composite discussed fixed grid finite element applicability fixed grid finite element method composite multiple irregular illustrated
# Original summary: conclusions availability method composite multiple irregular presented
# Predicted summary:  that the performance of the art method
#
#
# Review: based traditional ritz method presented three dimensional finite element analysis extracted results quite new vast variety results including results compression compression tension shear shear compression load cases considered discussed detail
# Original summary: present approach results extracted based galerkin type
# Predicted summary:  the proposed method is robust to the
#
#
# Review: subjected supersonic flow performance measure approach based first order reliability method incorporates probabilistic constraints search minimum mass panel optimization results given uncertainties panel boundary conditions non deterministic thickness design variables
# Original summary: topological distribution material differs deterministic uncertain panels
# Predicted summary:  the proposed method is robust to the
#
#
# Review: displacements transverse displacement respectively material properties assumed graded thickness direction according power law distribution terms volume fractions constituents convergence test comparison studies performed thin thick plates demonstrate accuracy present formulation
# Original summary: proposed element capable modeling thin thick plates
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: coupled physical processes solid skeleton deformation fluid flow fracture pore spaces surrounding porous medium hydraulic fracture propagation crucial provide correct solution problem fluid driven fracture porous media poroelastic effects significant
# Original summary: zone fluid length crack growth obtained solution
# Predicted summary:  the proposed method is robust to the
#
#
# Review: shell structures studied show applicability effectiveness proposed procedure good results analysis optimization using developed solid shell element obtained comparison reference analytical solutions obtained using solid shell finite element available code
# Original summary: involving diffuse approximation model pattern search optimization
# Predicted summary:  that the effectiveness of the art method
#
#
# Review: energy modes compared existing triangular shear deformable plate elements pass patch tests thick thin plates formulation present element simple perhaps simple possible number numerical examples tested showing convergence accuracy element
# Original summary: shows satisfactory convergence performance possesses high accuracy
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: reaction diffusion equation used update level set function several numerical examples prescribed target frequencies different initial shapes provided demonstrate proposed method provide clear optimized structures design negative bulk modulus acoustic
# Original summary: examples successfully obtain optimized shapes negative bulk
# Predicted summary:  planes to create in the spline matching
#
#
# Review: mixed mode thermal problems linear elastic fracture mechanics results compared published theoretical solutions based displacement method stress method crack closure integral conjunction local smoothing technique well integral method advantages discussed
# Original summary: gauss integration domain influence nodal density accuracy
# Predicted summary:  and impact of the fractional navier stokes
#
#
# Review: modeled elastic perfectly plastic material meshes consist second order finite elements numerical results demonstrate present methodology capable predicting adequate accuracy load displacement response even analyses involving large translations loaded boundary
# Original summary: numerical results good agreement limit analysis solutions
# Predicted summary:  results for the use of the proposed
#
#
# Review: buckling problems various boundary conditions covered analysis results show small size effects significant beam thickness small become negligible increasing beam thickness results believed first known open literature used benchmark studies
# Original summary: locking excellent agreement achieved present results literature
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: increase strip curvature force parameters decrease increasing asymmetry factor speed asymmetric factor influences strip bending significantly first attempt carry kind research surface roughness based real surface asymmetric rolling thin strip
# Original summary: attempt modelling surface roughness asymmetric thin strip
# Predicted summary:  results for the use of the art
#
#
# Review: carried varying graphite validate model finite element results compared machining test results carried compacted graphite iron material related paper turns simulated experimentally observed cutting force chip formation compare fairly well
# Original summary: experimental cutting forces chip compare fairly well
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: comparative assessment performed based conventional lsm based model parameter updating comparative study illustrated help two example problems using artificially generated input responses generally observed based identifies better lsm based approach
# Original summary: based approach based identifies better based approach
# Predicted summary:  that the performance of the art system
#
#
# Review: simulate distribution damage layer static cyclic loading fatigue crack growth aluminum panel also modeled using simple approach developed authors shown possible decrease propagation implementing appropriate composite patch dimensional material properties
# Original summary: patch width crack growth rate panel decreased
# Predicted summary:  results for the precise of mobile structures
#
#
# Review: field plate thickness described polynomial series influences length thickness ratio aspect ratio boundary conditions material property temperature critical buckling investigated numerical results circular rectangular plates provided validate effectiveness proposed method
# Original summary: studies conducted show good performance present method
# Predicted summary:  and electronic event multi multi spheres wet
#
#
# Review: method separation determination limit load variability tubes stochastic formulation based monte carlo simulation implemented shown imperfections lead substantial reduction buckling load thus taken account via realistic description stochastic field modeling
# Original summary: buckling load type loading affect failure modes
# Predicted summary:  the proposed method is robust to the
#
#
# Review: achieved layer base soil respectively based dataset validation method could also inverse compute modulus variation top layer due temperature profile average error attained three examples cold regular hot weather conditions
# Original summary: improve engineering accuracy minimal effects numerical accuracy
# Predicted summary:  results for the precise of the internet
#
#
# Review: parts vehicle body also investigated derived good modeling practices applied couple industrial case studies car body level giving better insight potential pitfalls possible solutions beam concept modeling become accurate reliable
# Original summary: stage successful application methodology industrial case studies
# Predicted summary:  the proposed method is robust to the
#
#
# Review: boundary conditions wear simulation circle two kinds namely shape rectangular section investigated paper sealing force important evaluate sealing capability effect wear reflected change sealing force numerical results supply suggestion applications
# Original summary: suitable low fluid pressure high speed environment
# Predicted summary:  the proposed method is robust to the
#
#
# Review: thereafter employing proposed elements presented simple algorithm analysis proposed elements used nonlinear analysis structures response compared obtained researchers results numerical examples indicate capability robustness proposed elements predicting deformation response structures
# Original summary: continuous discrete models provide good accuracy faster
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: equations presented describe cure kinetics thermal energy balance flow process general purpose finite element package multiphysics capabilities used simulating non isothermal process degrees cure temperature field distribution different cross sections
# Original summary: analyzed non isothermal press process behavior validated
# Predicted summary:  the proposed method is robust to the
#
#
# Review: predicts different performance large enough memory access latency validates intuition dynamic programming algorithm performs better machines validate several predictions made model using empirical measurements highly many core machine namely nvidia
# Original summary: asymptotic model helpful algorithm design many cores
# Predicted summary:  the proposed method is robust to the
#
#
# Review: finite element code specific fields transfer procedures automatic adaptation time loading sequences also presented efficiency robustness proposed strategy validated examples show good agreement experimentally observed crack paths large inelastic strains
# Original summary: sequence adapted size number fully damaged elements
# Predicted summary:  planes to create or in realistic hospital
#
#
# Review: spatial temporal scales model construction data driven based upon principles mean square error minimization conditional expectations stochastic estimation results indicate need model spatial temporal scales order improve accuracy resolved simulations
# Original summary: results indicate ability improve reliability resolved simulations
# Predicted summary:  the proposed method is robust to the
#
#
# Review: high computational efficiency improve identification accuracy recommendations optimal settings virtual experiments given well relevant statistical processing techniques proposed efficiency developed approach confirmed simulation study shows accuracy evaluating stiffness matrix elements
# Original summary: evaluation technique statistical processing experimental data matrix
# Predicted summary:  the proposed method is robust to the
#
#
# Review: shrinkage tendon relaxation stiffness matrix composed material geometric stiffness matrices numerical examples show proposed model well predict long term behavior prestressed concrete beams time dependent effects important influence structural behavior
# Original summary: considered interaction different time dependent effects considered
# Predicted summary:  results for the use of the art
#
#
# Review: behaviour response uniform modification strains hierarchical displacement modes introduced end results indicate robust behaviour comparable accuracy comparison mixed variational enhanced assumed strain elements full reduced integration structural problem classes undertaken
# Original summary: laws displacement variational element comparable accuracy elements
# Predicted summary:  the proposed method to the proposed method
#
#
# Review: properties concrete designed accommodate experimentally defined properties code practice recommendations well research results reported literature quality model assessed using set testing problems supported experimental data results obtained conventional finite elements
# Original summary: assessed using experimental monitoring data conform solutions
# Predicted summary:  results for the decision of mobile structures
#
#
# Review: models approaches took account rotation alignment molecular chain segments establishing stress strain relationship large deformation amorphous polymers model later extended three dimensional deformation recently developed model based molecular interaction capture
# Original summary: established two geometries two cross head speeds
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: particle interactions developed finite element formulation verified classical finite element simulation benchmark problems fracture simulation using proposed particle based finite element formulation demonstrated conclusions future work drawn based current investigation
# Original summary: accurate efficient robust simulating elastic fracture problems
# Predicted summary:  the proposed of the proposed method are
#
#
# Review: variations care must however taken introducing pressure enhancement helps mitigate pressure stress field perturbed equilibrium algorithm based dynamic relaxation radial return stress calculations presented matrix free calculations dealing stress dependent
# Original summary: free algorithm solving steady state flow problems
# Predicted summary:  way for create in the spline settings
#
#
# Review: long period time paper proposes method enables one switch beam model transient dynamic analysis thus allows one reduce computational cost preserving good accuracy method validated comparisons reference solution computed simulation
# Original summary: initialization techniques investigated energy consistency switch demonstrated
# Predicted summary:  the proposed method is robust to the
#
#
# Review: point algorithm multiplier mechanism series numerical experiments shows proposed model performs well elastic problems achieves context plastic analysis takes advantage absence volumetric locking piecewise constant interpolation stress field within element
# Original summary: saving relevant features context three dimensional analysis
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: error construction admissible fields global replaced resolution several local problems lower cpu costs key point domain decomposition based error estimation fact inter subdomain communication needed present illustrate strategy evaluate benefits
# Original summary: admissible field using domain decomposition illustrate strategy
# Predicted summary:  the proposed method is robust to the
#
#
# Review: force based formulation present model provides efficient tool buckling analysis two layer shear deformable beam column arbitrary support loading conditions finally two numerical applications presented order assess performance proposed formulation
# Original summary: shear deformable beams arbitrary support loading conditions
# Predicted summary:  results for the precise of the internet
#
#
# Review: solution norm continuous time priori error estimates proved case linear approximation space used numerical test performed order compare performance two iterative processes also results presented theoretical analysis confirmed numerical examples
# Original summary: computational cost picard block iterative methods proposed
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: accurate identified lie group partitioned method finite element rods involving large rotations displacements numerical examples allow verify algorithm presents excellent long term energy behavior along exact conservation associated symmetries system
# Original summary: size energy drift bounded exponentially long times
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: finite number rectangular impulses sufficient time duration applied impulse force estimated newton raphson based iterative residual method validity present method justified numerical experiment analyzing time response five layered damped beam
# Original summary: estimated residual based newton raphson iteration algorithm
# Predicted summary:  results for the precise of mobile structures
#
#
# Review: combination composition explosive steel best performing designs shown commonly possess following characteristics depths greater half shell thickness spacing within range approximately shell thickness shell thicknesses many times smaller shell radius
# Original summary: thickness shell many times smaller shell radius
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: temperature field using uniform profile average value specially low resistivity materials shown however always possible attenuation likely predicted mainly high radial thermal gradients high material flow temperature distribution taken account
# Original summary: attenuation likely predicted temperature distribution taken account
# Predicted summary:  that the minimum drive of the internet
#
#
# Review: area pressure force developed model exhibited good agreement numerical results especially intermediate large strains hence foundations development mechanistic contact models suitable simulations granular materials high relative densities discrete element method
# Original summary: captured numerical results model generalised loading conditions
# Predicted summary:  the proposed method is robust to the
#
#
# Review: newly inserted nodes discrete condition employed determine related nodal variables dynamic examples using adaptive meshing presented seen predictions look realistic deep predicted avoided yet required number nodes kept relatively small
# Original summary: new nodes predicted shapes appear realistic avoided
# Predicted summary:  the proposed of the art of the
#
#
# Review: locality maximize use chip memory increase notably performance gpu computing numerical experiments show proposed matrix free gpu instance achieve significant speedup classical sparse matrix cpu implementation using similar iterative solver
# Original summary: speedup respect sparse matrix cpu implementation achieved
# Predicted summary:  results for the use of the art
#
#
# Review: pole concept investigate alternative options implementation geometrically exact beam theory currently available context theory fixed pole concept first introduced thoroughly researched series subsequent papers context simple material polar material concept
# Original summary: assess new formulation respect invariance path dependence
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: local relative error indicators multi node computations finally developed based idea verify validity proposed method three typical numerical examples carried examples demonstrate nearly optimal distributions macroscopic nodes obtained employing proposed
# Original summary: nearly optimal distribution macroscopic nodes found using
# Predicted summary:  the proposed method for the proposed method
#
#
# Review: studied reinforced concrete beam subjected four point bending nonlocal model provides mesh independent load displacement curves strain profiles whereas peak loads strain profiles obtained crack band model depend element size
# Original summary: approaches investigated model yields mesh independent results
# Predicted summary:  the proposed method is robust to the
#
#
# Review: terms stiffness load distribution local response terms stress fields calculation times results show reduced model proposed able reduce calculation times still providing good estimate mechanical quantities needed study multi joints
# Original summary: high precision load distribution local stress field
# Predicted summary:  the proposed method is robust to the
